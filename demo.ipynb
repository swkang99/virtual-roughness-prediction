# %%
import copy
import yaml

from src.loocv import loocv
from src.model.factory import create_model

# %%
with open("config.yaml", "r", encoding="utf-8") as f:
    base_conf = yaml.safe_load(f)

# %%
model_list = [
        # "lr",
        # "svr",
        # "ann",
        # "cnn_1d_scirep",
        "cnn_1d_4ha",
    ]

# %%
for model_name in model_list:
    conf = copy.deepcopy(base_conf)
    conf["model"] = model_name

    print(f"\n===== Running LOOCV for {model_name} =====")
    loocv(conf, model_builder=create_model)
# Out:
# ===== Running LOOCV for cnn_1d_4ha =====
# Device: cuda
# Precomputing features for all samples...
# Precompute features: 100%|██████████| 100/100 [02:01<00:00,  1.22s/sample]
# Starting LOOCV training with 100 samples...
# LOOCV:   0%|          | 0/100 [00:00<?, ?fold/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3 conf["model"] = model_name
#       5 print(f"\n===== Running LOOCV for {model_name} =====")
# ----> 6 loocv(conf, model_builder=create_model)
#
# File c:\Users\kseon\virtual_tactile_property\src\loocv.py:56, in loocv(conf, model_builder)
#      47 test_dataset  = NormalizedSubset(base_dataset, test_indices, y_min, y_max)
#      49 model = model_builder(conf, input_dim=None, device=device)
#      51 model = train_one_fold(
#      52     model=model,
#      53     dataset=train_dataset,
#      54     device=device,
#      55     epochs=epochs,
# ---> 56     batch_size=batch_size,
#      57     lr=lr,
#      58     weight_decay=weight_decay,
#      59 )
#      61 preds, gts = evaluate_one_fold(
#      62     model=model,
#      63     dataset=test_dataset,
#    (...)
#      66     y_max=y_max,
#      67 )
#      69 predictions.append(preds)
#
# File c:\Users\kseon\virtual_tactile_property\src\model\factory.py:22, in create_model(conf, input_dim, device)
#      19 if model_name not in MODEL_REGISTRY:
#      20     raise ValueError(f"Unknown model: {model_name}")
# ---> 22 return MODEL_REGISTRY[model_name](conf, input_dim, device)
#
# File c:\Users\kseon\virtual_tactile_property\src\model\factory.py:13, in <lambda>(conf, input_dim, device)
#       1 from src.model.prediction.compared.cnn_1d_4ha import CNN1D4HA
#       2 # from src.model.prediction.compared.cnn_1d_scirep import CNN1DScirep
#       3 # from src.model.prediction.compared.ann import ANN
#       4 # from src.model.prediction.compared.lr import LinearRegressor
#       5 # from src.model.prediction.compared.svr import SVRModel
#       6 # from src.model.prediction.proposed import ProposedModel
#       8 MODEL_REGISTRY = {
#       9     "lr": lambda conf, input_dim, device: LinearRegressor(conf),
#      10     "svr": lambda conf, input_dim, device: SVRModel(conf),
#      11     "ann": lambda conf, input_dim, device: ANN(conf, input_dim=input_dim).to(device),
#      12     "cnn_1d_scirep": lambda conf, input_dim, device: CNN1DScirep(conf, feature_dim=input_dim).to(device),
# ---> 13     "cnn_1d_4ha": lambda conf, input_dim, device: CNN1D4HA(conf, feature_dim=input_dim).to(device),
#      14 }
#      16 def create_model(conf, input_dim=None, device=None):
#      17     model_name = conf["model"]
#
# TypeError: __init__() got an unexpected keyword argument 'feature_dim'
